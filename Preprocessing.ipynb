# %% [markdown]
# <a href="https://colab.research.google.com/github/EngrAnsar/EngrAnsar/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Title:
# # Data Preprocessing, Cleaning, visualization of
# ## Dataset name: "Wine Dataset "

# %% [markdown]
# **importing Dataset**

# %% [markdown]
# **We need three Libraries for data manipulation.cleaning, visualization.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
from sklearn.datasets import load_wine
import pandas as pd

# Load the wine dataset, which returns a Bunch object
wine = load_wine()

# Create a DataFrame using the 'data' and 'feature_names' attributes of the Bunch object
wine_df = pd.DataFrame(data=wine.data, columns=wine.feature_names)

print(wine_df.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# ## **A- Data inpections**

# %% [markdown]
# **1-checking ist five rows**

# %%
wine_df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# **2-checking last five rows**

# %%
wine_df.tail()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
# ...

# %% [markdown]
# **3-checking details**

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# **4.Checking Rows and Coloumns:**

# %%
wine_df.shape
# Out:
# (178, 13)

# %% [markdown]
# **5.Column Names**

# %%
wine_df.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %% [markdown]
# **6.Data Types for Preprocessing**

# %%
wine_df.dtypes
# Out:
# alcohol                         float64
# malic_acid                      float64
# ash                             float64
# alcalinity_of_ash               float64
# magnesium                       float64
# total_phenols                   float64
# flavanoids                      float64
# nonflavanoid_phenols            float64
# proanthocyanins                 float64
# color_intensity                 float64
# hue                             float64
# od280/od315_of_diluted_wines    float64
# proline                         float64
# dtype: object

# %% [markdown]
# **7.Label-based Data Selection (row and column)**

# %%
wine_df.loc[2]
# Out:
# alcohol                           13.16
# malic_acid                         2.36
# ash                                2.67
# alcalinity_of_ash                 18.60
# magnesium                        101.00
# total_phenols                      2.80
# flavanoids                         3.24
# nonflavanoid_phenols               0.30
# proanthocyanins                    2.81
# color_intensity                    5.68
# hue                                1.03
# od280/od315_of_diluted_wines       3.17
# proline                         1185.00
# Name: 2, dtype: float64

# %% [markdown]
# **8.Index-based Data Selection (row and column)**

# %%
wine_df.iloc[:,[2,4,8]]
# Out:
#       ash  magnesium  proanthocyanins
# 0    2.43      127.0             2.29
# 1    2.14      100.0             1.28
# 2    2.67      101.0             2.81
# 3    2.50      113.0             2.18
# 4    2.87      118.0             1.82
# ..    ...        ...              ...
# 173  2.45       95.0             1.06
# 174  2.48      102.0             1.41
# 175  2.26      120.0             1.35
# 176  2.37      120.0             1.46
# 177  2.74       96.0             1.35
#
# [178 rows x 3 columns]

# %% [markdown]
# **Applying mathematical fuctions**

# %%
wine_df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %% [markdown]
# # B-Data Cleaning

# %% [markdown]
# **1-checking Missing Values**

# %%
wine_df.isnull()
# Out:
#      alcohol  malic_acid    ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      False       False  False              False      False          False
# 1      False       False  False              False      False          False
# 2      False       False  False              False      False          False
# 3      False       False  False              False      False          False
# 4      False       False  False              False      False          False
# ..       ...         ...    ...                ...        ...            ...
# 173    False       False  False              False      False          False
# 174    False       False  False              False      False          False
# 175    False       False  False              False      False          False
# 176    False       False  False              False      False          False
# 177    False       False  False              False      False          False
#
# ...

# %% [markdown]
# **2."Non-Null Values in Dataset"**

# %%
wine_df.notnull()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0       True        True  True               True       True           True
# 1       True        True  True               True       True           True
# 2       True        True  True               True       True           True
# 3       True        True  True               True       True           True
# 4       True        True  True               True       True           True
# ..       ...         ...   ...                ...        ...            ...
# 173     True        True  True               True       True           True
# 174     True        True  True               True       True           True
# 175     True        True  True               True       True           True
# 176     True        True  True               True       True           True
# 177     True        True  True               True       True           True
#
# ...

# %% [markdown]
# **3.Remove Missing Values**

# %%
wine_df.dropna()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# **4.Fill Missing Values**

# %%
wine_df.interpolate()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# **5.Checking Duplicate Records**

# %%
wine_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# Length: 178, dtype: bool

# %% [markdown]
# **6.Removing Duplicate Records**

# %%
wine_df.drop_duplicates()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %% [markdown]
# # **C-Numerical functions**

# %% [markdown]
# **1-mean**

# %%
wine_df.mean(numeric_only=True)
# Out:
# alcohol                          13.000618
# malic_acid                        2.336348
# ash                               2.366517
# alcalinity_of_ash                19.494944
# magnesium                        99.741573
# total_phenols                     2.295112
# flavanoids                        2.029270
# nonflavanoid_phenols              0.361854
# proanthocyanins                   1.590899
# color_intensity                   5.058090
# hue                               0.957449
# od280/od315_of_diluted_wines      2.611685
# proline                         746.893258
# dtype: float64

# %% [markdown]
# **2-standard deviation**

# %%
wine_df.std(numeric_only=True)
# Out:
# alcohol                           0.811827
# malic_acid                        1.117146
# ash                               0.274344
# alcalinity_of_ash                 3.339564
# magnesium                        14.282484
# total_phenols                     0.625851
# flavanoids                        0.998859
# nonflavanoid_phenols              0.124453
# proanthocyanins                   0.572359
# color_intensity                   2.318286
# hue                               0.228572
# od280/od315_of_diluted_wines      0.709990
# proline                         314.907474
# dtype: float64

# %% [markdown]
# **3-Median**

# %%
wine_df.median(numeric_only=True)
# Out:
# alcohol                          13.050
# malic_acid                        1.865
# ash                               2.360
# alcalinity_of_ash                19.500
# magnesium                        98.000
# total_phenols                     2.355
# flavanoids                        2.135
# nonflavanoid_phenols              0.340
# proanthocyanins                   1.555
# color_intensity                   4.690
# hue                               0.965
# od280/od315_of_diluted_wines      2.780
# proline                         673.500
# dtype: float64

# %% [markdown]
# # Visualization

# %% [markdown]
# **Single line Graph**

# %%
import matplotlib.pyplot as plt

plt.plot(wine_df['alcohol'])
plt.xlabel("Wine Index")
plt.ylabel("Alcohol")
plt.title("Alcohol Trend")
plt.show()

# %% [markdown]
# **Multiple Line Graph**

# %%
plt.plot(wine_df['alcohol'], label='Alcohol')
plt.plot(wine_df['malic_acid'], label='Malic Acid')
plt.legend()
plt.title("Multiple Feature Trend")
plt.show()

# %% [markdown]
# **Bar Graph**

# %%
wine_df[['alcohol','magnesium','proline']].mean().plot(kind='bar')
plt.title("Average of Selected Features")
plt.ylabel("Mean Value")
plt.show()

# %% [markdown]
# **Histrogram**

# %%
plt.hist(wine_df['alcohol'], bins=10)
plt.xlabel("Alcohol")
plt.ylabel("Frequency")
plt.title("Alcohol Distribution")
plt.show()

# %% [markdown]
# **Scatter Graph**

# %%
plt.scatter(wine_df['alcohol'], wine_df['color_intensity'])
plt.xlabel("Alcohol")
plt.ylabel("Color Intensity")
plt.title("Alcohol vs Color Intensity")
plt.show()

# %%
# Load the Iris dataset
wine_df = load_wine()
x = wine_df.data  # Features
y = wine_df.target  # Target variable

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)

# %%
# Train a logistic regression model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
import numpy as np
y_pred_discrete = np.rint(y_pred).astype(int)
accuracy = accuracy_score(y_test, y_pred_discrete)
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 0.94

# %% [markdown]
# **Conclusion**

# %% [markdown]
# ### The wines_SPA dataset provides a clear overview of Spanish wines, including their types, wineries, prices, and ratings. The line graph revealed the distribution of wines across different years, while the multiple line graph highlighted trends in both price and rating. Bar and pie charts helped identify the most common wine types and the top wineries, and histograms showed the distribution of price and rating. The scatter plot demonstrated a general trend that higher-priced wines tend to have higher ratings. Overall, the analysis offered valuable insights into wine characteristics, popularity, and trends, making the dataset easier to understand and interpret visually.
